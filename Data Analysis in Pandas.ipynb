# %%
import pandas as pd
import numpy as np

# %%
pwd
# Out:
# 'C:\\Users\\Judiciary'

# %% [markdown]
# ### Importing csv file

# %%
court_data = pd.read_csv(r"C:\Users\Judiciary\Desktop\moringa\data\court_data.csv")
court_data
# Out:
# C:\Users\Judiciary\AppData\Local\Temp\ipykernel_2596\680225708.py:1: DtypeWarning: Columns (6,14,16,17) have mixed types. Specify dtype option on import or set low_memory=False.
#   court_data = pd.read_csv(r"C:\Users\Judiciary\Desktop\moringa\data\court_data.csv")
#                     court  date_dd date_mon  date_yyyy   caseid_type  \
# 0       363052 High Court     23.0      May     2023.0         HCCRC
# 1       363052 High Court     19.0      Sep     2022.0        HCFP&A
# 2       363052 High Court     21.0      Jun     2023.0      HCCCMISC
# 3       363052 High Court     21.0      Sep     2022.0  HCCRMISCAPPL
# 4       363052 High Court      6.0      Mar     2023.0         HCCRA
# ...                   ...      ...      ...        ...           ...
# 357224   63035 High Court     29.0      Jun     2023.0         HCCRA
# 357225   63035 High Court      5.0      Jun     2023.0         HCCRA
# 357226   63035 High Court     27.0      Jun     2023.0         HCCRA
# ...

# %%
sample_data = pd.read_excel(r"C:\Users\Judiciary\Desktop\moringa\data\Sample Data.xlsx")
sample_data
# Out:
#       Unnamed: 0                               Unnamed: 1 Unnamed: 2  \
# 0            NaN  Court station name: \n(Entry required.)        NaN
# 1            NaN                                      NaN        NaN
# 2            NaN               \nToday's date\n\n\n\n\n\n        NaN
# 3            NaN                                      Day      Month
# 4            NaN                                        3        Apr
# ...          ...                                      ...        ...
# 2156         NaN                                       28        Apr
# 2157         NaN                                       28        Apr
# 2158         NaN                                       28        Apr
# 2159         NaN                                       28        Apr
# 2160         NaN                                       28        Apr
#
#      Unnamed: 3                                    Unnamed: 4 Unnamed: 5  \
# ...
